# %%
dropTable = "drop table if exists silver.crm.customers"
spark.sql(dropTable).show()
sqlString = "drop schema if exists silver.crm cascade"
spark.sql(sqlString).show()

dropTable = "drop table if exists silver.historical.customers"
spark.sql(dropTable).show()
sqlString = "drop schema if exists silver.historical cascade"
spark.sql(sqlString).show()
dropTable = "drop table if exists bronze.crm.customers"
spark.sql(dropTable).show()
dropTable = "drop table if exists bronze.crm.customer_reviews"
spark.sql(dropTable).show()
# Out:
# ++
# ||
# ++
# ++
# ++
# ||
# ++
# ++
# ++
# ||
# ++
# ++
# ++
# ||
# ++
# ++
# ++
# ||
# ++
# ++
# ++
# ||
# ++
# ++
